# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = 20, 10

# %%
from naive_bayes_classifier.load_data import str2word_bag
from naive_bayes_classifier.configure import *

# %%
from naive_bayes_classifier.back_test_utils import *

# %%
from sklearn.metrics import precision_score, f1_score, accuracy_score, recall_score
# Out:
# Intel(R) Data Analytics Acceleration Library (Intel(R) DAAL) solvers for sklearn enabled: https://intelpython.github.io/daal4py/sklearn.html

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
import pickle
import pandas as pd
import numpy as np

# %%
with open("rst.pkl", "rb") as fp:
    rst_lst = pickle.load(fp)

# %%
Y_FILE = "./USTREASURY-REALYIELD.csv"

# %%
rate_se = pd.read_csv(Y_FILE, index_col=0)["10 YR"]
rate_se.index = pd.DatetimeIndex(rate_se.index)
rate_se = rate_se.sort_index()

# %%
rate_se.plot();

# %% [markdown]
# ## Overall reval profile

# %% [markdown]
# Reval/preval analysis is a widely used tools in market impact analysis. It is defined as the price movement before and after a certain incident happens in the market. In this case study, we first look at 5-year treasury yield movement before and after the Fed speech as a whole. Then we might want to generate features through the text and then to look at if the reval of differnet groups have diverged profiles.

# %%
def get_reval(prev_n=10, rev_n=10):
    y_lst = []

    for ctt in rst_lst:
        prev = rate_se[rate_se.index <= pd.to_datetime(ctt[1])][-prev_n:].values
        rev = rate_se[rate_se.index > pd.to_datetime(ctt[1])][:rev_n].values
        this = prev[-1]
        
        tt = np.log(np.hstack((prev, rev)) / this)
        tt = np.where((np.abs(tt) == np.inf), 0.0, tt)
        tt = np.nan_to_num(tt)
        
        y_lst.append(tt)
    return y_lst

# %%
def evaluate(y_true, y_pred):
    return accuracy_score(y_true, y_pred), precision_score(y_true, y_pred, average="weighted"), recall_score(y_true, y_pred, average="weighted"), f1_score(y_true, y_pred, average="weighted")

# %%
rev_lst = get_reval()
# Out:
# C:\Users\hoore\Miniconda3\envs\work\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':
# C:\Users\hoore\Miniconda3\envs\work\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in log
#   if __name__ == '__main__':
# C:\Users\hoore\Miniconda3\envs\work\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in true_divide
#   if __name__ == '__main__':
# C:\Users\hoore\Miniconda3\envs\work\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in true_divide
#   if __name__ == '__main__':

# %%
tt = np.vstack(rev_lst)

# %%
plt.plot(tt.T);

# %% [markdown]
# ## Roughly look at the distribution of revals

# %%
import seaborn as sb

# %%
sb.distplot(tt[:, 10]);

# %%
sb.distplot(tt[:, 14]);

# %%
sb.distplot(tt[:, 19]);

# %%
y_raw = tt[:, 14]

# %%
p = 0.2

# %%
y_neg = (y_raw < np.quantile(y_raw, p)).astype(np.int)

# %%
y_pos = (y_raw > np.quantile(y_raw, 1-p)).astype(np.int)

# %%
np.sum(y_neg) / len(y_raw), np.sum(y_pos) / len(y_raw)
# Out:
# (0.20025839793281655, 0.20025839793281655)

# %%
benchmark_change = np.log(rate_se).diff().dropna().values
# Out:
# C:\Users\hoore\Miniconda3\envs\work\lib\site-packages\pandas\core\series.py:853: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\hoore\Miniconda3\envs\work\lib\site-packages\pandas\core\series.py:853: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\hoore\Miniconda3\envs\work\lib\site-packages\pandas\core\algorithms.py:1977: RuntimeWarning: invalid value encountered in subtract
#   out_arr[res_indexer] = arr[res_indexer] - arr[lag_indexer]

# %%
y_benchmark_neg = (benchmark_change < np.quantile(y_raw, p)).astype(np.int)

# %%
y_benchmark_pos = (benchmark_change > np.quantile(y_raw, 1-p)).astype(np.int)

# %%
np.sum(y_benchmark_neg) / len(benchmark_change), np.sum(y_benchmark_pos) / len(benchmark_change)
# Out:
# (0.08654101406955136, 0.07698433766923281)

# %%
X_dct = [str2word_bag(itm[2], STOP_CHARS, STOP_WORDS, to_lower=True) for itm in rst_lst]

# %%
X = pd.DataFrame(X_dct).fillna(0)

# %%
y = np.zeros_like(y_raw) - y_neg + y_pos

# %%
y_pred4 = rolling_test_single(ExtraTreesClassifier(n_estimators=100, n_jobs=-1), X.values, y, 500)

# %%
evaluate(y, y_pred4)

# %%
y_pred5 = rolling_test_single(GaussianNB(), X.values, y, 500)

# %%
evaluate(y, y_pred5)
# Out:
# (0.5775193798449613,
#  0.4764795366464687,
#  0.5775193798449613,
#  0.48790089185533864)

# %%
model = MultinomialNB()

# %%
model.fit(X, y)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
y_pred = model.predict(X)

# %%
evaluate(y, y_pred)
# Out:
# (0.8837209302325582,
#  0.8848409181670646,
#  0.8837209302325582,
#  0.8833138445086687)

# %%
plt.plot(np.cumsum(y_pred4 * y_raw))

# %%
model.feature_count_
# Out:
# array([[194., 176.,  57., ...,   0.,   0.,   0.],
#        [550., 636., 188., ...,   1.,   4.,   1.],
#        [131., 151.,  79., ...,   0.,   0.,   0.]])

# %%
prob = model.feature_log_prob_

# %%
prob.shape
# Out:
# (3, 33188)

# %%
prob_df = pd.DataFrame(np.exp(prob), index=[-1, 0, 1], columns=X.columns).T

# %%
dist = prob_df.std(axis=1).sort_values(ascending=False)

# %%
dist
# Out:
# financial       1.067632e-03
# policy          1.017319e-03
# risk            9.538914e-04
# community       9.165531e-04
# rate            9.073209e-04
#                     ...
# process--in     1.813546e-07
# level--which    1.813546e-07
# policy--for     1.813546e-07
# rotate          1.813546e-07
# staffed         1.813546e-07
# Length: 33188, dtype: float64

# %%
from sklearn.svm import SVC

# %%
model2 = SVC()

# %%
model2.fit(X, y)
# Out:
# C:\Users\hoore\Miniconda3\envs\work\lib\site-packages\daal4py\sklearn\svm\svm.py:321: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
y_pred2 = model2.predict(X)

# %%
evaluate(y, y_pred2)
# Out:
# (0.6059431524547804,
#  0.7622335796346139,
#  0.6059431524547804,
#  0.4638994234981714)

# %%
model3 = ExtraTreesClassifier()

# %%
model3.fit(X[:700], y[:700])
# Out:
# C:\Users\hoore\Miniconda3\envs\work\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#                      max_depth=None, max_features='auto', max_leaf_nodes=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#                      oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)

# %%
y_pred3 = model3.predict(X[700:])

# %%
evaluate(y[700:], y_pred3)
# Out:
# (0.5945945945945946,
#  0.4136310223266745,
#  0.5945945945945946,
#  0.48787248787248777)

# %% [markdown]
# ## TODO: Only use these as features.

# %% [markdown]
# ## 1. Generate word bags using similar codes in naive_bayes_classifier

# %% [markdown]
# ## 2. The reval characterisctic is captured by n day rate movement, we first set n == 1

# %% [markdown]
# ## 3. Fit a naive bayes model to learn about which word/words could have the most impact of the rate.

# %% [markdown]
# ## Future work
# 1. Use title information and treat title worlds differently as those in the body of the article
# 2. Cross-validation over time
# 3. Word2Vec
