# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = 20, 10

# %%
from sklearn.naive_bayes import *
from sklearn.ensemble import *
# Out:
# Intel(R) Data Analytics Acceleration Library (Intel(R) DAAL) solvers for sklearn enabled: https://intelpython.github.io/daal4py/sklearn.html

# %%
from naive_bayes_classifier.load_data import str2word_bag
from naive_bayes_classifier.configure import *
from back_test import *
from utils import *

# %%
import pickle
import pandas as pd
import numpy as np

# %%
rate_se, rst_lst = load_data()

# %%
rate_se.plot();

# %% [markdown]
# ## Overall reval profile

# %% [markdown]
# Reval/preval analysis is a widely used tools in market impact analysis. It is defined as the price movement before and after a certain incident happens in the market. In this case study, we first look at 5-year treasury yield movement before and after the Fed speech as a whole. Then we might want to generate features through the text and then to look at if the reval of differnet groups have diverged profiles.

# %%
rev_lst = get_reval(rst_lst, rate_se)
# Out:
# C:\Users\hoore\Documents\workspace\nlp\nlp_project\utils.py:33: RuntimeWarning: divide by zero encountered in log
#   tt = np.log(np.hstack((prev, rev)) / this)
# C:\Users\hoore\Documents\workspace\nlp\nlp_project\utils.py:33: RuntimeWarning: invalid value encountered in log
#   tt = np.log(np.hstack((prev, rev)) / this)
# C:\Users\hoore\Documents\workspace\nlp\nlp_project\utils.py:33: RuntimeWarning: divide by zero encountered in true_divide
#   tt = np.log(np.hstack((prev, rev)) / this)
# C:\Users\hoore\Documents\workspace\nlp\nlp_project\utils.py:33: RuntimeWarning: invalid value encountered in true_divide
#   tt = np.log(np.hstack((prev, rev)) / this)

# %%
rev_ar = np.vstack(rev_lst)

# %%
plt.plot(rev_ar.T);

# %% [markdown]
# ## Roughly look at the distribution of revals

# %% [markdown]
# import seaborn as sb

# %% [markdown]
# sb.distplot(tt[:, 10]);

# %% [markdown]
# sb.distplot(tt[:, 14]);

# %% [markdown]
# sb.distplot(tt[:, 19]);

# %%
y_raw = rev_ar[:, 10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-afa140b763ca> in <module>()
# ----> 1 y_raw = tt[:, 10]
#
# NameError: name 'tt' is not defined

# %%
p = 0.2

# %%
y_neg = (y_raw < np.quantile(y_raw, p)).astype(np.int)

# %%
y_pos = (y_raw > np.quantile(y_raw, 1-p)).astype(np.int)

# %%
np.sum(y_neg) / len(y_raw), np.sum(y_pos) / len(y_raw)

# %%
benchmark_change = np.log(rate_se).diff().dropna().values

# %%
y_benchmark_neg = (benchmark_change < np.quantile(y_raw, p)).astype(np.int)

# %%
y_benchmark_pos = (benchmark_change > np.quantile(y_raw, 1-p)).astype(np.int)

# %%
np.sum(y_benchmark_neg) / len(benchmark_change), np.sum(y_benchmark_pos) / len(benchmark_change)

# %%
X_dct = [str2word_bag(itm[2], STOP_CHARS, STOP_WORDS, to_lower=True) for itm in rst_lst]

# %%
X = pd.DataFrame(X_dct).fillna(0)

# %%
y = np.zeros_like(y_raw) - y_neg + y_pos

# %%
y.dump("y.pkl")

# %%
y_raw.dump("y_raw.pkl")

# %%
y_pred4 = rolling_test_single(ExtraTreesClassifier(n_estimators=50, n_jobs=-1), X.values, y, 300)

# %%
evaluate(y, y_pred4)

# %%
plt.plot(np.cumsum(y_raw * y_pred4))

# %% [markdown]
# y_pred5 = rolling_test_single(GaussianNB(), X.values, y, 500)

# %% [markdown]
# evaluate(y, y_pred5)

# %% [markdown]
# y_pred6 = rolling_test_single(MultinomialNB(), X.values, y, 500)

# %% [markdown]
# evaluate(y, y_pred6)

# %% [markdown]
# y_pred7 = rolling_test_single(BaggingClassifier(base_estimator=MultinomialNB()), X.values, y, 500)

# %% [markdown]
# evaluate(y, y_pred7)

# %% [markdown]
# model = MultinomialNB()

# %% [markdown]
# model.fit(X, y)

# %% [markdown]
# y_pred = model.predict(X)

# %% [markdown]
# evaluate(y, y_pred)

# %% [markdown]
# plt.plot(np.cumsum(y_pred4 * y_raw))

# %% [markdown]
# model.feature_count_

# %% [markdown]
# prob = model.feature_log_prob_

# %% [markdown]
# prob.shape

# %% [markdown]
# prob_df = pd.DataFrame(np.exp(prob), index=[-1, 0, 1], columns=X.columns).T

# %% [markdown]
# dist = prob_df.std(axis=1).sort_values(ascending=False)

# %% [markdown]
# dist

# %% [markdown]
# from sklearn.svm import SVC

# %% [markdown]
# model2 = SVC()

# %% [markdown]
# model2.fit(X, y)

# %% [markdown]
# y_pred2 = model2.predict(X)

# %% [markdown]
# evaluate(y, y_pred2)

# %% [markdown]
# model3 = ExtraTreesClassifier()

# %% [markdown]
# model3.fit(X[:700], y[:700])

# %% [markdown]
# y_pred3 = model3.predict(X[700:])

# %% [markdown]
# evaluate(y[700:], y_pred3)

# %% [markdown]
# ## TODO: Only use these as features.

# %% [markdown]
# ## -1. Add title features

# %% [markdown]
# ## 0. Plot "alpha" decay

# %% [markdown]
# ## 1. Generate word bags using similar codes in naive_bayes_classifier

# %% [markdown]
# ## 2. The reval characterisctic is captured by n day rate movement, we first set n == 1

# %% [markdown]
# ## 3. Fit a naive bayes model to learn about which word/words could have the most impact of the rate.

# %% [markdown]
# ## 4. Rolling cross-validation

# %% [markdown]
# ## 5. Try CNN-like structure.

# %% [markdown]
# # Use title as feature

# %%
X_title_dct = [str2word_bag(itm[0], STOP_CHARS, STOP_WORDS, to_lower=True) for itm in rst_lst]

# %%
X_title = pd.DataFrame(X_title_dct).fillna(0)

# %%
y_pred8 = rolling_test_single(ExtraTreesClassifier(n_estimators=50, n_jobs=-1), X_title.values, y, 300)

# %%
evaluate(y, y_pred8)

# %%
plt.plot(np.cumsum(y_raw * y_pred8))

# %%
X_total = pd.concat([X, X_title], axis=1)

# %%
X_total

# %%
y_pred9 = rolling_test_single(ExtraTreesClassifier(n_estimators=50, n_jobs=-1), X_total.values, y, 300)

# %%
evaluate(y, y_pred9)

# %%
plt.plot(np.cumsum(y_raw * y_pred9))
